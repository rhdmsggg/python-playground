# %%
family = ["mother", "father", "mimi", "dori mura"]
for x in family:
  print(x, len(x))
# Out:
# mother 6
# father 6
# mimi 4
# dori mura 9

# %%
list(range(2,7))
range(2,7)
# Out:
# range(2, 7)

# %%
num = (int(input()))
for x in range(0, num):
  print(num)
# Out:
#  3
# 3
# 3
# 3

# %%
num = int(input())
for x in range(1,num + 1):
  print(x , x**2)
# Out:
# 5
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25

# %%
range(5)

for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
for x in [1,2,3,4]:
  print(x)
else:
  print("리스트의 원소를 모두 출력했어요")
# Out:
# 1
# 2
# 3
# 4
# 리스트의 원소를 모두 출력했어요

# %%
for x in [1,2,3,4]:
  if x % 3 :
    print(x)
  else :
    break
else:
  print("리스트의 원소를 모두 출력했어요")
# Out:
# 1
# 2

# %%
countdown = 5
while countdown > 0:
  print(countdown)
  countdown -= 1
  if input() == '중단':
    break
else:
  print('발사!')
# Out:
# 5
# 3
# 4
#
# 3
#
# 2
#
# 1
#
# 발사!

# %%
a_list = [3, 4, 62, 27, 83, 956, 26, 58, 3, 78, 168, 64, 78]

def pirnt_list(a):
  for i in a:
    print(i)

def boy():
  print('i am a boy')
  print('You are a girl')

pirnt_list(a_list)
boy()
# Out:
# 3
# 4
# 62
# 27
# 83
# 956
# 26
# 58
# 3
# 78
# 168
# 64
# 78
# i am a boy
# You are a girl

# %%
def numOfdigits(int):
  print(len(str(int)))

numOfdigits(1234890)
# Out:
# 7

# %%
def exam():
  for i in range(2, 10):
    for j in range(1, 10):
      print(i, " * " , j , " = ", i*j)

exam()
# Out:
# 2  *  1  =  2
# 2  *  2  =  4
# 2  *  3  =  6
# 2  *  4  =  8
# 2  *  5  =  10
# 2  *  6  =  12
# 2  *  7  =  14
# 2  *  8  =  16
# 2  *  9  =  18
# 3  *  1  =  3
# 3  *  2  =  6
# 3  *  3  =  9
# 3  *  4  =  12
# 3  *  5  =  15
# 3  *  6  =  18
# 3  *  7  =  21
# 3  *  8  =  24
# 3  *  9  =  27
# 4  *  1  =  4
# 4  *  2  =  8
# 4  *  3  =  12
# 4  *  4  =  16
# 4  *  5  =  20
# 4  *  6  =  24
# 4  *  7  =  28
# 4  *  8  =  32
# 4  *  9  =  36
# 5  *  1  =  5
# 5  *  2  =  10
# 5  *  3  =  15
# 5  *  4  =  20
# 5  *  5  =  25
# 5  *  6  =  30
# 5  *  7  =  35
# 5  *  8  =  40
# 5  *  9  =  45
# 6  *  1  =  6
# 6  *  2  =  12
# 6  *  3  =  18
# 6  *  4  =  24
# 6  *  5  =  30
# 6  *  6  =  36
# 6  *  7  =  42
# 6  *  8  =  48
# 6  *  9  =  54
# 7  *  1  =  7
# 7  *  2  =  14
# 7  *  3  =  21
# 7  *  4  =  28
# 7  *  5  =  35
# 7  *  6  =  42
# 7  *  7  =  49
# 7  *  8  =  56
# 7  *  9  =  63
# 8  *  1  =  8
# 8  *  2  =  16
# 8  *  3  =  24
# 8  *  4  =  32
# 8  *  5  =  40
# ...

# %%
def f2(x):
  a = 3
  b = 5
  y = a * x + b
  print(y)

d = f2(10)

print(d)
# Out:
# 35
# None

# %%
def triangle(a : int, b : int):
  return a * b

print(triangle(3, 4))
# Out:
# 12

# %%
def korean_number(int):
  str_list = ['일', '이', '삼', '사', '오', '육', '칠', '팔', '구' , '십']
  return str_list[int - 1]

print(korean_number(1))
print(korean_number(7))
# Out:
# 일
# 칠

# %%
def triple(x):
  return print(x * 3)

triple(2)
triple('x')
# Out:
# 6
# xxx

# %%
from datetime import datetime
today = datetime.today()
today.year

def korean_age(year):
  return print(today.year - year)

korean_age(1999)
# Out:
# 27

# %%
# 원금 p, 단기 이율 r, 기간 t
def simple_interest(p,r,t):
  return p * r * t

def simple_interest_amount(p,r,t):
  return p + simple_interest(p, r, t)

simple_interest(10000000, 0.03875, 5)

simple_interest(1100000, 0.05, 5/12)

simple_interest_amount(10000000, 0.03875, 5)

simple_interest_amount(1100000, 0.05, 5/12)
# Out:
# 1122916.6666666667

# %%
newjins = ["철수", "영희", "민수", "지현", "서연"]
ive = ["영희", "민수", "지수", "서연", "하나"]
espa = ["철수", "지현", "지수", "서연", "나영"]

for i in newjins:
  if (i in ive and i not in espa):
    print("뉴진스와 아이브를 좋아하지만 에스파는 좋아하지 않는", i)
# Out:
# 뉴진스와 아이브를 좋아하지만 에스파는 좋아하지 않는 영희
# 뉴진스와 아이브를 좋아하지만 에스파는 좋아하지 않는 민수

# %%
# 거꾸로 배열해도 같은 단어 혹은 문장이 되는 것을 회문이라고 한다 (palindrome)
def palindrome(text):
  text = text.lower().replace(" ", "")
  if (text == text[::-1]):
    return True
  else:
    return False

palindrome('An na')
# Out:
# True

# %%
def sumOfDigits_Short(num):
    return sum(int(c) for c in str(num))

def sumOfDigits(num):
  total = 0
  for i in str(num):
    total += int(i)
  return total

sumOfDigits(643)
# Out:
# 13

# %%
score = [0, 0, 2, 4, 7, 7, 9]
score += [11, 11, 13, 18]
score += [20]

stem_leaf = [[], [], []]

"""for s in score:
  d = s / 10
  m = s % 10
  stem_leaf[int(d)].append(m)

stem_leaf[0]"""


for s in score:
    d, m = divmod(s, 10)
    stem_leaf[d].append(m)


for i in range(len(stem_leaf)):
    print(f'{i}: {stem_leaf[i]}')
# Out:
# 0: [0, 0, 2, 4, 7, 7, 9]
# 1: [1, 1, 3, 8]
# 2: [0]

# %%
def read(text):
  name, value = text.split(":")
  value = value.strip()

  if "~" in value:
    min, max = value.split("~")
    min = min.replace("cm","")
    max = max.replace("cm", "")
    return name, min, max

  if "cm" in value:
    num = int(value.split("cm")[0])
    if "이상" in value:
      return name, num, None
    elif "이하" in value:
      return name, None, num
  else:
    num = "-"
    return name, None, None


ridename, cmmin, cmmax = read(input())
print("이름:", ridename)
print("하한:", cmmin)
print("상한:", cmmax)
# Out:
# 와일드 윙: 110cm 이상
# 이름: 와일드 윙
# 하한: 110
# 상한: None
